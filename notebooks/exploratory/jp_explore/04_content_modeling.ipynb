# %%
import pandas as pd
import surprise
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
meta = pd.read_csv('../../../data/movies_metadata.csv')
# Out:
# C:\Users\jaker\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
meta = meta.set_index('id')

# %%
movies = pd.read_csv('../../../data/movies.csv', dtype=object).set_index('movieId')
links = pd.read_csv('../../../data/links.csv', dtype=object).set_index('movieId')

# %%
movies2 = movies.join(links)

# %%
movies2
# Out:
#                                              title  \
# movieId
# 1                                 Toy Story (1995)
# 2                                   Jumanji (1995)
# 3                          Grumpier Old Men (1995)
# 4                         Waiting to Exhale (1995)
# 5               Father of the Bride Part II (1995)
# ...                                            ...
# 193581   Black Butler: Book of the Atlantic (2017)
# 193583                No Game No Life: Zero (2017)
# 193585                                Flint (2017)
# 193587         Bungo Stray Dogs: Dead Apple (2018)
# 193609         Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres   imdbId  tmdbId
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy  0114709     862
# 2                         Adventure|Children|Fantasy  0113497    8844
# 3                                     Comedy|Romance  0113228   15602
# 4                               Comedy|Drama|Romance  0114885   31357
# 5                                             Comedy  0113041   11862
# ...                                              ...      ...     ...
# 193581               Action|Animation|Comedy|Fantasy  5476944  432131
# 193583                      Animation|Comedy|Fantasy  5914996  445030
# 193585                                         Drama  6397426  479308
# 193587                              Action|Animation  8391976  483455
# 193609                                        Comedy  0101726   37891
#
# [9742 rows x 4 columns]

# %%
meta['imdb_id'] = meta['imdb_id'].str[-7:]

# %%
meta = meta.set_index('imdb_id')

# %%
movies2 = movies2.set_index('imdbId').drop('tmdbId', axis=1)

# %%
movies2
# Out:
#                                              title  \
# imdbId
# 0114709                           Toy Story (1995)
# 0113497                             Jumanji (1995)
# 0113228                    Grumpier Old Men (1995)
# 0114885                   Waiting to Exhale (1995)
# 0113041         Father of the Bride Part II (1995)
# ...                                            ...
# 5476944  Black Butler: Book of the Atlantic (2017)
# 5914996               No Game No Life: Zero (2017)
# 6397426                               Flint (2017)
# 8391976        Bungo Stray Dogs: Dead Apple (2018)
# 0101726        Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres
# imdbId
# 0114709  Adventure|Animation|Children|Comedy|Fantasy
# 0113497                   Adventure|Children|Fantasy
# 0113228                               Comedy|Romance
# 0114885                         Comedy|Drama|Romance
# 0113041                                       Comedy
# ...                                              ...
# 5476944              Action|Animation|Comedy|Fantasy
# 5914996                     Animation|Comedy|Fantasy
# 6397426                                        Drama
# 8391976                             Action|Animation
# 0101726                                       Comedy
#
# [9742 rows x 2 columns]

# %%
movies3 = movies2.join(meta.overview)

# %%
movies3.dropna(inplace=True)

# %%
movies3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9510 entries, 0000417 to 7158814
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     9510 non-null   object
#  1   genres    9510 non-null   object
#  2   overview  9510 non-null   object
# dtypes: object(3)
# memory usage: 297.2+ KB

# %%
movies3.sample(10)
# Out:
#                                                      title  \
# 0115640                             Beautiful Thing (1996)
# 0783233                                   Atonement (2007)
# 0047577                           This Island Earth (1955)
# 2084989                              Upstream Color (2013)
# 2140203  Wolf Children (Okami kodomo no ame to yuki) (2...
# 0081480                        Seems Like Old Times (1980)
# 2582802                                    Whiplash (2014)
# 0296310                             The Blue Planet (2001)
# 3553442                       Whiskey Tango Foxtrot (2016)
# 0214388                                   100 Girls (2000)
#
#                           genres  \
# 0115640            Drama|Romance
# 0783233        Drama|Romance|War
# 0047577                   Sci-Fi
# 2084989  Romance|Sci-Fi|Thriller
# 2140203        Animation|Fantasy
# 0081480           Comedy|Romance
# 2582802                    Drama
# 0296310              Documentary
# 3553442               Comedy|War
# 0214388           Comedy|Romance
#
#                                                   overview
# 0115640  A pair of teenage boys growing up in a working...
# 0783233  As a 13-year-old, fledgling writer Briony Tall...
# 0047577  Aliens have landed and are hiding on Earth, bu...
# 2084989  A man and woman are drawn together, entangled ...
# 2140203  Hana, a nineteen-year-old college student, fal...
# 0081480  Writer Nick Gardenia is kidnapped from his Cal...
# 2582802  Under the direction of a ruthless instructor, ...
# 0296310  The Blue Planet, the definitive exploration of...
# 3553442  In 2002, cable news producer Kim Barker (Tina ...
# 0214388  This sexy, teen-comedy is about a freshman, Ma...

# %%
movies3.genres = movies3.genres.apply(lambda x: x.replace('|', ' '))

# %%
movies3['description'] = movies3.genres + ' ' +  movies3.overview

# %%
movies3.sample(10)
# Out:
#         index                                              title  \
# 5259  0239948               Saving Silverman (Evil Woman) (2001)
# 8373  1637688                                     In Time (2011)
# 943   0061722                               Graduate, The (1967)
# 7954  1291584                                     Warrior (2011)
# 7651  1094249  Hotel Chevalier (Part 1 of 'The Darjeeling Lim...
# 760   0056732  Exterminating Angel, The (Ángel exterminador, ...
# 396   0043014      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 5236  0236027        Flickering Lights (Blinkende lygter) (2000)
# 2398  0094898                           Coming to America (1988)
# 7191  0780653                                Wolfman, The (2010)
#
#                             genres  \
# 5259                Comedy Romance
# 8373         Crime Sci-Fi Thriller
# 943           Comedy Drama Romance
# 7954                         Drama
# 7651                         Drama
# 760   Comedy Drama Fantasy Mystery
# 396        Drama Film-Noir Romance
# 5236           Action Comedy Crime
# 2398                Comedy Romance
# 7191               Horror Thriller
#
#                                                overview  \
# 5259  A pair of buddies conspire to save their best ...
# 8373  In the not-too-distant future the aging gene h...
# 943   A recent college graduate finds himself in a l...
# 7954  The inspirational story of an estranged family...
# 7651  Grief? Depression? Ambiguity in a Paris hotel ...
# 760   The guests at an upper-class dinner party find...
# 396   A hack screenwriter writes a screenplay for a ...
# 5236  Four small gangsters from Copenhagen trick a g...
# 2398  Prince Akeem, heir to the throne of Zamunda, l...
# 7191  Lawrence Talbot, an American man on a visit to...
#
#                                                   words
# 5259  Comedy Romance A pair of buddies conspire to s...
# 8373  Crime Sci-Fi Thriller In the not-too-distant f...
# 943   Comedy Drama Romance A recent college graduate...
# 7954  Drama The inspirational story of an estranged ...
# 7651  Drama Grief? Depression? Ambiguity in a Paris ...
# 760   Comedy Drama Fantasy Mystery The guests at an ...
# 396   Drama Film-Noir Romance A hack screenwriter wr...
# 5236  Action Comedy Crime Four small gangsters from ...
# 2398  Comedy Romance Prince Akeem, heir to the thron...
# 7191  Horror Thriller Lawrence Talbot, an American m...

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2) ,min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(movies3['overview'])

# %%
cosines = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
movies3 = movies3.reset_index()
titles = movies3['title']
indices = pd.Series(movies3.index, index=movies3['title'])

# %%
def recommend(title):
    idx = indices[title]
    sim_scores = list(enumerate(cosines[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:10]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
recommend('Thor: The Dark World (2013)')
# Out:
# 7223                                          Thor (2011)
# 9217                                Thor: Ragnarok (2017)
# 9490    While You Were Fighting: A Thor Mockumentary (...
# 3451                    NeverEnding Story III, The (1994)
# 1711                             Dark Crystal, The (1982)
# 8505                           Killing Them Softly (2012)
# 8154                                    Prometheus (2012)
# 5592    Babylon 5: The Legend of the Rangers: To Live ...
# 6995          Wal-Mart: The High Cost of Low Price (2005)
# Name: title, dtype: object

# %%
list(enumerate(['johm','jake','donna']))
# Out:
# [(0, 'johm'), (1, 'jake'), (2, 'donna')]

# %%
for num, name in enumerate(['johm','jake','donna']):
    print(num, name*2)
# Out:
# 0 johmjohm
# 1 jakejake
# 2 donnadonna

# %%
recommend('Hotel Transylvania 2 (2015)')
# Out:
# 2541                 Dead Poets Society (1989)
# 7288                     Dracula Untold (2014)
# 36                     Jazz Singer, The (1927)
# 8107    Best Exotic Marigold Hotel, The (2011)
# 2065                   Vampire Hunter D (1985)
# 4420          Million Dollar Hotel, The (2001)
# 4542            Fracchia contro Dracula (1985)
# 665               Grass Is Greener, The (1960)
# 4595                      Hideous Kinky (1998)
# Name: title, dtype: object

# %%
movies3.to_csv('../../../src/movie_descriptions.csv')

# %%
pd.read_csv('../../../src/movie_descriptions.csv')
# Out:
#       Unnamed: 0    index                                              title  \
# 0              0      417  Trip to the Moon, A (Voyage dans la lune, Le) ...
# 1              1      439                     The Great Train Robbery (1903)
# 2              2      516                          The Electric Hotel (1908)
# 3              3     4972                      Birth of a Nation, The (1915)
# 4              4     6333                20,000 Leagues Under the Sea (1916)
# ...          ...      ...                                                ...
# 9505        9505  6840134                        The Putin Interviews (2017)
# 9506        9506  6878486  Norm Macdonald: Hitler's Dog, Gossip & Tricker...
# 9507        9507  6987652                      Oh, Hello: On Broadway (2017)
# 9508        9508  7044010  Rory Scovel Tries Stand-Up for the First Time ...
# 9509        9509  7158814       LEGO DC Super Hero Girls: Brain Drain (2017)
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1                       Crime Western
# 2             Animation Comedy Sci-Fi
# 3                           Drama War
# 4             Action Adventure Sci-Fi
# ...                               ...
# 9505               (no genres listed)
# 9506                           Comedy
# 9507                           Comedy
# 9508                           Comedy
# 9509                        Animation
#
#                                                overview
# 0     A Trip to The Moon is a science fiction film f...
# 1     The clerk at the train station is assaulted an...
# 2     According to the rapid strides that electricit...
# 3     The Birth of A Nation is a silent film from 19...
# 4     Captain Nemo has built a fantastic submarine f...
# ...                                                 ...
# 9505  Academy Award-winning filmmaker, Oliver Stone ...
# 9506  In this new stand-up special, Norm Macdonald d...
# 9507  Two delusional geriatrics reveal curious pasts...
# 9508  Comedian Rory Scovel storms the stage in Atlan...
# 9509  When Supergirl, Wonder Woman, Batgirl, Bumbleb...
#
# [9510 rows x 5 columns]
