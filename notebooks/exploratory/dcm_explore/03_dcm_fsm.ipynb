# %% [markdown]
# # Time to get down to some modeling

# %%
# imports 
import pandas as pd
import numpy as np


from surprise import Dataset, Reader
from surprise import accuracy

from surprise.model_selection import train_test_split, cross_validate

from surprise.prediction_algorithms import SVD, SVDpp, SlopeOne, NMF, NormalPredictor, KNNBaseline, KNNBasic, KNNWithMeans, KNNWithZScore, BaselineOnly, CoClustering

# %% [markdown]
# using my filtered dataframe with thresholds for movies and users

# %%
df = pd.read_csv('../../../data/joined_dfs_lc')
df.shape
# Out:
# (100836, 7)

# %%
reader = Reader(rating_scale=(0, 5))
# Load the dataset 
data = Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader)

# sample random trainset and testset
# test set is made of 25% of the ratings.
trainset, testset = train_test_split(data, test_size=.25)

# %%
# instantiate the algorithm
algo = SVDpp()

# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.8720
# 0.8719712611260318

# %%
# Run 3-fold cross-validation and print results
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVDpp on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.8718  0.8727  0.8697  0.8714  0.0013
# MAE (testset)     0.6689  0.6678  0.6676  0.6681  0.0006
# Fit time          674.78  649.39  668.42  664.20  10.79
# Test time         20.05   19.58   21.61   20.42   0.87
# {'test_rmse': array([0.87176279, 0.87271706, 0.86965529]),
#  'test_mae': array([0.66887946, 0.66778529, 0.66756038]),
#  'fit_time': (674.7831881046295, 649.3946812152863, 668.4170718193054),
#  'test_time': (20.05371618270874, 19.582926034927368, 21.60849094390869)}

# %%
algo.predict(5,'Blade Runner (1982)')
# Out:
# Prediction(uid=5, iid='Blade Runner (1982)', r_ui=None, est=4.00460414925547, details={'was_impossible': False})

# %%
algo.predict(15,'Matrix, The (1999)')
# Out:
# Prediction(uid=15, iid=1, r_ui=None, est=3.1212547093839014, details={'was_impossible': False})

# %%
algo.predict(2,60756)
# Out:
# Prediction(uid=2, iid=60756, r_ui=None, est=3.5957409537815046, details={'was_impossible': False})

# %%
# Let's tune
algo2 = SVDpp(n_factors=50)

# Train the algorithm on the trainset, and predict ratings for the testset
algo2.fit(trainset)
predictions = algo2.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.8722
# 0.8722392488769417

# %%
# thank you to Susan Li for this helpful code

def get_Iu(uid):
    """ return the number of items rated by given user
    args: 
      uid: the id of the user
    returns: 
      the number of items rated by the user
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """ return number of users that have rated given item
    args:
      iid: the raw id of the item
    returns:
      the number of users that have rated the item.
    """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0
    
df = pd.DataFrame(predictions, columns=['uid', 'iid', 'rui', 'est', 'details'])
df['Iu'] = df.uid.apply(get_Iu)
df['Ui'] = df.iid.apply(get_Ui)
df['err'] = abs(df.est - df.rui)
best_predictions = df.sort_values(by='err')[:100]
worst_predictions = df.sort_values(by='err')[-100:]

# %%
pd.set_option('display.max_rows', 500)
best_predictions.head(100)
# Out:
#        uid                                                iid  rui       est  \
# 24324  382                                 Matrix, The (1999)  5.0  5.000000
# 583     32                   Shawshank Redemption, The (1994)  5.0  5.000000
# 14429  515                                Forrest Gump (1994)  5.0  5.000000
# 13051  610                                Blade Runner (1982)  5.0  5.000000
# 162    555          Star Wars: Episode IV - A New Hope (1977)  5.0  5.000000
# 1265   480                            Schindler's List (1993)  5.0  5.000000
# 24152  417                   Shawshank Redemption, The (1994)  5.0  5.000000
# 12227  251                                Forrest Gump (1994)  5.0  5.000000
# 1241   122          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  5.0  5.000000
# 13943  171                              Cool Hand Luke (1967)  5.0  5.000000
# 3000   313  Raiders of the Lost Ark (Indiana Jones and the...  5.0  5.000000
# 17141  523  Howl's Moving Castle (Hauru no ugoku shiro) (2...  5.0  5.000000
# 9336    45                                      Snatch (2000)  5.0  5.000000
# 4641   452                            Schindler's List (1993)  5.0  5.000000
# 6863   382                                   Inception (2010)  5.0  5.000000
# 7962   494                                 Matrix, The (1999)  5.0  5.000000
# 22955  380                               Groundhog Day (1993)  5.0  5.000000
# 1058   414                   Shawshank Redemption, The (1994)  5.0  5.000000
# 992     58                   Shawshank Redemption, The (1994)  5.0  5.000000
# 4040   597  Star Wars: Episode VI - Return of the Jedi (1983)  5.0  5.000000
# 19164  182                                Pulp Fiction (1994)  5.0  5.000000
# 290    380                                Pulp Fiction (1994)  5.0  5.000000
# 22045   57                              Godfather, The (1972)  5.0  5.000000
# 17860  380                                   Inception (2010)  5.0  5.000000
# 22057  267  Star Wars: Episode VI - Return of the Jedi (1983)  5.0  5.000000
# 7315    43                            Bonnie and Clyde (1967)  5.0  5.000000
# 17716  603                                  Casablanca (1942)  5.0  5.000000
# 8174   515                                  Fight Club (1999)  5.0  5.000000
# 19052   58                            Schindler's List (1993)  5.0  5.000000
# 16081  305                              Godfather, The (1972)  5.0  5.000000
# 369    572                            Schindler's List (1993)  5.0  5.000000
# 975    555                                  Braveheart (1995)  5.0  5.000000
# 19765  464                   Shawshank Redemption, The (1994)  5.0  5.000000
# 18697  597          Star Wars: Episode IV - A New Hope (1977)  5.0  5.000000
# 3328   523                             Green Mile, The (1999)  5.0  5.000000
# 12918  135                                 Matrix, The (1999)  5.0  5.000000
# 12479  171             One Flew Over the Cuckoo's Nest (1975)  5.0  5.000000
# 7069   414                               Almost Famous (2000)  5.0  5.000000
# 18700  391                            Schindler's List (1993)  5.0  5.000000
# 8359   391                              Apocalypse Now (1979)  5.0  5.000000
# 21399  523  Lord of the Rings: The Return of the King, The...  5.0  5.000000
# 14106  393                                  Fight Club (1999)  5.0  5.000000
# 12626  414             Monty Python and the Holy Grail (1975)  5.0  5.000000
# 18546  122                              Godfather, The (1972)  5.0  5.000000
# 3299   171                   Silence of the Lambs, The (1991)  5.0  5.000000
# 5360   382                                     Memento (2000)  5.0  5.000000
# 9887   523                            Dark Knight, The (2008)  5.0  5.000000
# 11123   18                                Finding Nemo (2003)  4.0  3.998705
# 6148    68  Good, the Bad and the Ugly, The (Buono, il bru...  3.5  3.498535
# 7197   307                         Little Mermaid, The (1989)  3.0  3.001527
# 1371   182                                  Adaptation (2002)  4.5  4.501641
#
#                          details    Iu   Ui       err
# 24324  {'was_impossible': False}   218  218  0.000000
# 583    {'was_impossible': False}    79  231  0.000000
# 14429  {'was_impossible': False}    22  255  0.000000
# 13051  {'was_impossible': False}   984   91  0.000000
# 162    {'was_impossible': False}   446  191  0.000000
# 1265   {'was_impossible': False}   637  174  0.000000
# 24152  {'was_impossible': False}    59  231  0.000000
# 12227  {'was_impossible': False}    18  255  0.000000
# 1241   {'was_impossible': False}   222  129  0.000000
# 13943  {'was_impossible': False}    62   48  0.000000
# 3000   {'was_impossible': False}   253  142  0.000000
# 17141  {'was_impossible': False}    54   27  0.000000
# 9336   {'was_impossible': False}   289   71  0.000000
# 4641   {'was_impossible': False}   149  174  0.000000
# 6863   {'was_impossible': False}   218  103  0.000000
# 7962   {'was_impossible': False}    19  218  0.000000
# 22955  {'was_impossible': False}   911  114  0.000000
# 1058   {'was_impossible': False}  2006  231  0.000000
# 992    {'was_impossible': False}    82  231  0.000000
# 4040   {'was_impossible': False}   320  139  0.000000
# 19164  {'was_impossible': False}   721  237  0.000000
# 290    {'was_impossible': False}   911  237  0.000000
# 22045  {'was_impossible': False}   345  144  0.000000
# 17860  {'was_impossible': False}   911  103  0.000000
# 22057  {'was_impossible': False}    44  139  0.000000
# 7315   {'was_impossible': False}    94   26  0.000000
# 17716  {'was_impossible': False}   722   75  0.000000
# 8174   {'was_impossible': False}    22  168  0.000000
# 19052  {'was_impossible': False}    82  174  0.000000
# 16081  {'was_impossible': False}   502  144  0.000000
# 369    {'was_impossible': False}   118  174  0.000000
# 975    {'was_impossible': False}   446  177  0.000000
# 19765  {'was_impossible': False}    96  231  0.000000
# 18697  {'was_impossible': False}   320  191  0.000000
# 3328   {'was_impossible': False}    54   83  0.000000
# 12918  {'was_impossible': False}   203  218  0.000000
# 12479  {'was_impossible': False}    62   95  0.000000
# 7069   {'was_impossible': False}  2006   67  0.000000
# 18700  {'was_impossible': False}   300  174  0.000000
# 8359   {'was_impossible': False}   300   82  0.000000
# 21399  {'was_impossible': False}    54  143  0.000000
# 14106  {'was_impossible': False}   101  168  0.000000
# 12626  {'was_impossible': False}  2006   98  0.000000
# 18546  {'was_impossible': False}   222  144  0.000000
# 3299   {'was_impossible': False}    62  212  0.000000
# 5360   {'was_impossible': False}   218  113  0.000000
# 9887   {'was_impossible': False}    54  122  0.000000
# 9237   {'was_impossible': False}   546   25  0.000002
# 19693  {'was_impossible': False}    71  110  0.000014
# 3977   {'was_impossible': False}   645   35  0.000015
# 15894  {'was_impossible': False}   355  111  0.000067
# 23226  {'was_impossible': False}    36    7  0.000082
# 21813  {'was_impossible': False}   911    8  0.000091
# 17069  {'was_impossible': False}   134   66  0.000124
# 23017  {'was_impossible': False}    62   50  0.000142
# 2325   {'was_impossible': False}   538   35  0.000147
# 17964  {'was_impossible': False}   960   70  0.000167
# 13655  {'was_impossible': False}   137   45  0.000168
# 19591  {'was_impossible': False}   117    1  0.000190
# 25038  {'was_impossible': False}    19   35  0.000216
# 3807   {'was_impossible': False}  1866   21  0.000220
# 24243  {'was_impossible': False}   194  142  0.000239
# 24042  {'was_impossible': False}   573    8  0.000298
# 14690  {'was_impossible': False}  2006   12  0.000316
# 6306   {'was_impossible': False}   281   16  0.000325
# 7067   {'was_impossible': False}  1016   79  0.000354
# 14612  {'was_impossible': False}   234   48  0.000356
# 723    {'was_impossible': False}   294   74  0.000374
# 14443  {'was_impossible': False}    16   24  0.000407
# 498    {'was_impossible': False}   155  110  0.000455
# 20830  {'was_impossible': False}   223   24  0.000459
# 1830   {'was_impossible': False}   111   60  0.000494
# 16871  {'was_impossible': False}    82   33  0.000565
# 24972  {'was_impossible': False}   234   74  0.000583
# 10212  {'was_impossible': False}   297   17  0.000622
# 11221  {'was_impossible': False}   462    5  0.000624
# 8360   {'was_impossible': False}  1866   92  0.000656
# 21924  {'was_impossible': False}   158    1  0.000662
# 15562  {'was_impossible': False}   665   38  0.000680
# 17136  {'was_impossible': False}   335   49  0.000689
# 9028   {'was_impossible': False}    94  122  0.000734
# 23957  {'was_impossible': False}    82   31  0.000742
# 18094  {'was_impossible': False}    67  127  0.000795
# 16712  {'was_impossible': False}   165   47  0.000915
# 15516  {'was_impossible': False}   538   44  0.000957
# 19109  {'was_impossible': False}   338    6  0.000980
# 13857  {'was_impossible': False}    89    3  0.000983
# 10235  {'was_impossible': False}   277   20  0.000989
# 21049  {'was_impossible': False}   107  103  0.000990
# 15851  {'was_impossible': False}    71   59  0.000993
# 20528  {'was_impossible': False}   215   18  0.001032
# 18662  {'was_impossible': False}  1407    5  0.001112
# 11339  {'was_impossible': False}  1581    0  0.001112
# 8085   {'was_impossible': False}   722    9  0.001162
# 23839  {'was_impossible': False}   275    3  0.001237
# 2853   {'was_impossible': False}  1866   48  0.001260
# 11123  {'was_impossible': False}   375  102  0.001295
# 6148   {'was_impossible': False}   960   54  0.001465
# 7197   {'was_impossible': False}   715   47  0.001527
# 1371   {'was_impossible': False}   721   34  0.001641

# %%
worst_predictions
# Out:
#        uid                                                iid  rui       est  \
# 23571  184                             The Emoji Movie (2017)  0.5  3.551966
# 8391   177                                   Bad Santa (2003)  0.5  3.554588
# 18498  483                              Secret Society (2002)  0.5  3.554722
# 24988  418          Mission: Impossible - Rogue Nation (2015)  0.5  3.557655
# 17425   51                     Star Trek: Insurrection (1998)  0.5  3.560755
# 24991  175                                        Stay (2005)  0.5  3.563384
# 10256  115                             American Beauty (1999)  1.0  4.076182
# 18646  354                                  Happy Feet (2006)  0.5  3.577040
# 22075   34      Lord of the Rings: The Two Towers, The (2002)  1.0  4.081258
# 24449  594  Exterminating Angel, The (Ángel exterminador, ...  0.5  3.588433
# 17456  483                                         Saw (2004)  0.5  3.588908
# 21168  {'was_impossible': False}   80   45  3.095199
# 15678  {'was_impossible': False}  911    5  3.097413
# 15138  {'was_impossible': False}  715   10  3.098072
# 10748  {'was_impossible': False}  722   11  3.100925
# 20422  {'was_impossible': False}   30   35  3.104056
# 16449  {'was_impossible': False}  194   21  3.107134
# 16510  {'was_impossible': False}  502   11  3.116104
# 3803   {'was_impossible': False}  170   53  3.129109
# 21335  {'was_impossible': False}  497   44  3.131741
# 5928   {'was_impossible': False}  446   32  3.132700
# 10214  {'was_impossible': False}  289    9  3.132909
# 12656  {'was_impossible': False}  388   27  3.156976
# 830    {'was_impossible': False}  101    9  3.158089
# 4344   {'was_impossible': False}  274   53  3.162558
# 9411   {'was_impossible': False}  253   21  3.165474
# 19000  {'was_impossible': False}  721    4  3.172588
# 1403   {'was_impossible': False}  343   34  3.174228
# 4021   {'was_impossible': False}   45    6  3.175805
# 18081  {'was_impossible': False}  446   10  3.182656
# 5977   {'was_impossible': False}  573   49  3.182839
# 14014  {'was_impossible': False}   85   11  3.183179
# 10431  {'was_impossible': False}  332   13  3.190163
# 19954  {'was_impossible': False}  343    2  3.203357
# 3221   {'was_impossible': False}  483    7  3.208299
# 5038   {'was_impossible': False}  274   29  3.221826
# 2576   {'was_impossible': False}  134  168  3.224495
# 9679   {'was_impossible': False}  722   25  3.226993
# 21618  {'was_impossible': False}  274    1  3.229751
# 23247  {'was_impossible': False}  343    2  3.244376
# 16816  {'was_impossible': False}  101   77  3.254664
# 17325  {'was_impossible': False}  388   51  3.255150
# 7910   {'was_impossible': False}   92   42  3.262337
# 1758   {'was_impossible': False}   95    0  3.266824
# 8170   {'was_impossible': False}   47   44  3.271934
# 4679   {'was_impossible': False}  483   22  3.283437
# 21719  {'was_impossible': False}   45   56  3.284219
# 1254   {'was_impossible': False}  618   37  3.287584
# 677    {'was_impossible': False}   37   11  3.289001
# 6471   {'was_impossible': False}  483   80  3.296539
# 12352  {'was_impossible': False}  199   21  3.300402
# 7505   {'was_impossible': False}   20   66  3.309839
# 7185   {'was_impossible': False}   26   60  3.318359
# 10244  {'was_impossible': False}   70    8  3.321703
# 24874  {'was_impossible': False}  170    1  3.329733
# 24912  {'was_impossible': False}   79   37  3.330406
# 7745   {'was_impossible': False}   68   83  3.334810
# 7968   {'was_impossible': False}  171   52  3.347914
# 22596  {'was_impossible': False}  489   32  3.356255
# 23157  {'was_impossible': False}  489  127  3.358379
# 25208  {'was_impossible': False}   87   77  3.360579
# 7360   {'was_impossible': False}   44   32  3.392285
# 12899  {'was_impossible': False}  170    3  3.421926
# 12824  {'was_impossible': False}   61    4  3.429645
# 4791   {'was_impossible': False}  101   45  3.434571
# 4036   {'was_impossible': False}   40  174  3.434848
# 19544  {'was_impossible': False}  444   16  3.440589
# 20204  {'was_impossible': False}  275   48  3.448204
# 2561   {'was_impossible': False}   21  113  3.454112
# 17556  {'was_impossible': False}  722   34  3.461817
# 6130   {'was_impossible': False}   20  142  3.482538
# 7211   {'was_impossible': False}  170    1  3.508549
# 20051  {'was_impossible': False}  170    0  3.508549
# 15298  {'was_impossible': False}  170    2  3.511923
# 10399  {'was_impossible': False}  299   21  3.518078
# 22627  {'was_impossible': False}  299   32  3.520586
# 16879  {'was_impossible': False}   22   53  3.531583
# 22076  {'was_impossible': False}   40   15  3.576542
# 18249  {'was_impossible': False}   45  140  3.591581
# 22238  {'was_impossible': False}  235    2  3.610577
# 21851  {'was_impossible': False}  170    0  3.610794
# 18983  {'was_impossible': False}  149   40  3.616492
# 2204   {'was_impossible': False}  170   20  3.621308
# 14481  {'was_impossible': False}  721  143  3.648981
# 10947  {'was_impossible': False}  137   25  3.650083
# 23427  {'was_impossible': False}   45   11  3.656660
# 5201   {'was_impossible': False}  170    2  3.679495
# 1821   {'was_impossible': False}  343    4  3.702343
# 19169  {'was_impossible': False}  101   14  3.708332
# 25112  {'was_impossible': False}  274   37  3.738051
# 5850   {'was_impossible': False}  223   58  3.783008
# 3456   {'was_impossible': False}   42   74  3.808721
# 7716   {'was_impossible': False}  101   26  3.885661
# 22205  {'was_impossible': False}  101   79  3.890591
# 20968  {'was_impossible': False}  101   91  3.969509
# 24590  {'was_impossible': False}  235   52  4.020221
# 18251  {'was_impossible': False}  235   32  4.039041
# 2560   {'was_impossible': False}  235   82  4.191390
# 10950  {'was_impossible': False}   61    8  4.500000

# %%
# Let's tune again
algo4 = SVDpp(n_factors=50, n_epochs=50,reg_all=0.05, verbose=True)

# Train the algorithm on the trainset, and predict ratings for the testset
algo4.fit(trainset)
predictions = algo4.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)
# Out:
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 20
#  processing epoch 21
#  processing epoch 22
#  processing epoch 23
#  processing epoch 24
#  processing epoch 25
#  processing epoch 26
#  processing epoch 27
#  processing epoch 28
#  processing epoch 29
#  processing epoch 30
#  processing epoch 31
#  processing epoch 32
#  processing epoch 33
#  processing epoch 34
#  processing epoch 35
#  processing epoch 36
#  processing epoch 37
#  processing epoch 38
#  processing epoch 39
#  processing epoch 40
#  processing epoch 41
#  processing epoch 42
#  processing epoch 43
#  processing epoch 44
#  processing epoch 45
#  processing epoch 46
#  processing epoch 47
#  processing epoch 48
#  processing epoch 49
# RMSE: 0.8639
# 0.863924686296065

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.6645
# 0.6644956302577323

# %%
# Let's tune again
algo6 = SVDpp(n_factors=100, n_epochs=100, lr_all=0.005, reg_all=0.4, verbose=True)

# Train the algorithm on the trainset, and predict ratings for the testset
algo6.fit(trainset)
predictions = algo6.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)
